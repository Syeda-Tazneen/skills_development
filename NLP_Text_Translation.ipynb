# %% [markdown]
# <a href="https://colab.research.google.com/github/Syeda-Tazneen/skills_development/blob/main/NLP_Text_Translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extract Text from PDF

# %%
#!pip install pdfminer.six

# %%
import numpy as np
import re # regular expression
from pdfminer.high_level import extract_text

# %%
pdf_extract = extract_text('Amitabh_Bachchan.pdf')
print(pdf_extract)
# Out:
# Amitabh Bachchan
#
# Amitabh  Bachchan  (pronounced  [əmɪˈt ̪ɑːbʱ  ˈbətːʃən];  born
# as  Amitabh  Srivastava;[1]  11  October  1942[9])  is  an  Indian
# actor,  film  producer,  television  host,  occasional  playback
# singer, and former politician actively engaged in Hindi cinema.
# With  a  cinematic  journey  spanning  over  five  decades,  he  has
# played  pivotal  roles  in  over  200  films.  Widely  recognised  as
# one  of  the  most  accomplished  and  influential  actors  in  the
# history  of  Indian  cinema.[10]  Bachchan  is  often  hailed  as  the
# Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as
# "Greatest  actor  of  the  century"  in  Hindi),  Star  of  the
# Millennium, or simply Big B.[11] His dominance in the Indian
# film  industry  during  the  1970s–80s  led  the  French  director
# François Truffaut to describe it as a "one-man industry".[12]
#
# Bachchan was born in 1942 in Allahabad (now Prayagraj) to
# ...

# %% [markdown]
# # Extract Images from PDF

# %%
#!pip install PyMuPDF
#!pip install pillow

# %%
import fitz
import PIL.Image
import io

# %%
pdf_image = fitz.open('Amitabh_Bachchan.pdf')
counter = 1

for i in range(len(pdf_image)):
    page = pdf_image[i]
    images = page.get_images()

    for image in images:
        base_img = pdf_image.extract_image(image[0])
        image_data = base_img["image"]
        img = PIL.Image.open(io.BytesIO(image_data))
        extension = base_img["ext"]
        img.save(open(f"Nitin{counter}.{extension}","wb"))
        counter +=1

# %%
len(pdf_image)
# Out:
# 41

# %% [markdown]
# # Transalation

# %%
# Hindi, Punjabi, Tamil, Kanadda, Oriya, Telgu
# French, chineese, German

# %% [markdown]
# # TextBlob : Translation purpose and it is NLP package

# %%
# !pip install -U textblob
# !python -m textblob.download_corpora

# %%
from textblob import TextBlob

# %%
language = TextBlob("台湾薪资停滞20年，历届政府都承诺解决，但一直没有改善。有调查显示低薪困境是年轻选民最重视的议题之一，将对候选人构成选举压力，长远更可能会损害台湾青年对民主政治的信心。台北的初冬早上，24岁的诗雅（化名）骑脚踏车到达中正区的办公大楼，这趟15分钟的“车程”只需5元（新台币，下同）。她对记者说：“反正我家离公司不远，重点是可以省交通费。”来自屏东的她独自在台北打拼，过着节衣缩食的生活。午休时间，她跑到附近的学校区小吃店，点了一碗70元的肉羹面。“现在物价涨的很凶，随便一个好吃一点的便当都要150到180块，我要把每顿饭的钱压缩在100块内。”这位职场新人大学毕业一年半，在中小型广告公司任职平面设计师，月薪三万元（约合950美元），公司偶尔会视乎专项发放奖金3000到6000元。")

# %%
language
# Out:
# TextBlob("台湾薪资停滞20年，历届政府都承诺解决，但一直没有改善。有调查显示低薪困境是年轻选民最重视的议题之一，将对候选人构成选举压力，长远更可能会损害台湾青年对民主政治的信心。台北的初冬早上，24岁的诗雅（化名）骑脚踏车到达中正区的办公大楼，这趟15分钟的“车程”只需5元（新台币，下同）。她对记者说：“反正我家离公司不远，重点是可以省交通费。”来自屏东的她独自在台北打拼，过着节衣缩食的生活。午休时间，她跑到附近的学校区小吃店，点了一碗70元的肉羹面。“现在物价涨的很凶，随便一个好吃一点的便当都要150到180块，我要把每顿饭的钱压缩在100块内。”这位职场新人大学毕业一年半，在中小型广告公司任职平面设计师，月薪三万元（约合950美元），公司偶尔会视乎专项发放奖金3000到6000元。")

# %%
language.translate(from_lang='zh-CN', to='hi')
# Out:
# TextBlob("ताइवान का वेतन 20 वर्षों से रुक गया है, और पिछली सरकार ने इसे हल करने का वादा किया है, लेकिन इसमें सुधार नहीं हुआ है। कुछ सर्वेक्षणों से पता चलता है कि कम -कम दुविधा युवा मतदाताओं के लिए सबसे महत्वपूर्ण मुद्दों में से एक है। यह उम्मीदवारों पर दबाव का गठन करेगा। लंबे समय में, यह लोकतांत्रिक राजनीति के बारे में ताइवान के युवाओं के विश्वास को नुकसान पहुंचाने की अधिक संभावना है। ताइपे में शुरुआती सर्दियों की सुबह में, 24 -वर्ष -वोल्ड शिया (छद्म नाम) ने झोंगज़ेंगेंग जिले में कार्यालय भवन में एक साइकिल की सवारी की। इस 15 -मिनट "ड्राइव" की लागत केवल 5 युआन (एनटी $, नीचे समान है)। उसने रिपोर्टर से कहा: "वैसे भी, मेरा परिवार कंपनी से दूर नहीं है। ध्यान परिवहन खर्चों को बचाने पर है।" उसने पिंग्तुंग से ताइपे में अकेले काम किया और कपड़े सिकोड़ते हुए कपड़े पहने। लंच ब्रेक में, वह पास के एक स्कूल डिस्ट्रिक्ट स्नैक बार में भाग गई और 70 युआन के मांस नूडल्स का एक कटोरा ऑर्डर किया। "अब कीमत बहुत भयंकर है। बस एक अधिक स्वादिष्ट दोपहर का भोजन 150 से 180 युआन है। मैं 100 युआन के भीतर प्रति भोजन 
# ...

# %%
language.translate(from_lang='zh-CN', to='pa')
# Out:
# TextBlob("ਤਾਈਵਾਨ ਦੀ ਤਨਖਾਹ 20 ਸਾਲਾਂ ਤੋਂ ਠਹਿਰ ਗਈ ਹੈ, ਅਤੇ ਪਿਛਲੀ ਸਰਕਾਰ ਨੇ ਇਸ ਦੇ ਹੱਲ ਲਈ ਵਾਅਦਾ ਕੀਤਾ ਸੀ, ਪਰ ਇਹ ਨਹੀਂ ਸੁਧਾਰਿਆ. ਕੁਝ ਸਰਵੇਖਣ ਦਰਸਾਉਂਦੇ ਹਨ ਕਿ ਲੋਅਰ-ਸਮਿੰਗ ਦੁਬਿਧਾ ਬੱਚਿਆਂ ਦੇ ਵੋਟਰਾਂ ਲਈ ਸਭ ਤੋਂ ਮਹੱਤਵਪੂਰਨ ਮੁੱਦੇ ਹਨ. ਇਹ ਉਮੀਦਵਾਰਾਂ 'ਤੇ ਦਬਾਅ ਬਣਾਏਗਾ. ਲੰਬੇ ਸਮੇਂ ਵਿਚ ਤਾਈਵਾਨ ਦੀ ਨੌਜਵਾਨਾਂ ਦਾ ਵਿਸ਼ਵਾਸ ਕਰਨ ਦੀ ਸਲਾਹ ਨੂੰ ਨੁਕਸਾਨ ਪਹੁੰਚਾਉਣ ਦੀ ਜ਼ਿਆਦਾ ਸੰਭਾਵਨਾ ਹੈ. ਟਾਇਪੇ ਵਿਚ ਸਰਦੀਆਂ ਦੀ ਸਵੇਰ ਦੇ ਸ਼ੁਰੂ ਵਿਚ 24 ਸਾਲਾ ਸਾਇਆਂ (ਉਪਨਾਮ) ਜ਼ੋਂਗਜ਼ੇਂਗ ਜ਼ਿਲ੍ਹੇ ਦੀ ਦਫ਼ਤਰ ਦੀ ਇਮਾਰਤ ਵਿਚ ਸਵਾਰ ਹੋ ਗਿਆ. ਇਹ 15-ਮਿਮੀਟ "ਡਰਾਈਵ" ਸਿਰਫ 5 ਯੂਆਨ (ਐਨਟੀ $, ਹੇਠਾਂ) ਹੈ. ਉਸਨੇ ਰਿਪੋਰਟਰ ਨੂੰ ਕਿਹਾ: "" ਫਿਰ ਵੀ ਮੇਰਾ ਪਰਿਵਾਰ ਕੰਪਨੀ ਤੋਂ ਬਹੁਤ ਦੂਰ ਨਹੀਂ ਹੈ. ਧਿਆਨ ਕੇਂਦ੍ਰਤ ਦੇ ਖਰਚਿਆਂ ਨੂੰ ਬਚਾਉਣ 'ਤੇ ਕੇਂਦ੍ਰਤ. "ਉਸਨੇ ਪਿੰਗਟੰਗ ਤੋਂ ਤਾਇਬਣੀ ਵਿਚ ਇਕੱਲੇ ਕੰਮ ਕੀਤਾ. ਦੁਪਹਿਰ ਦੇ ਖਾਣੇ ਦੇ ਬਰੇਕ ਤੇ, ਉਹ ਨੇੜੇ ਦੇ ਸਕੂਲ ਜ਼ਿਲ੍ਹਾ ਸਨੈਕ ਬਾਰ ਨੂੰ ਭੱਲੀ ਅਤੇ ਮੀਟ ਨੂਡਲਜ਼ ਦੇ 70 ਯੂਆਨ ਦਾ ਕਟੋਰੇ ਦਾ ਆਦੇਸ਼ ਦਿੱਤਾ. "ਹੁਣ ਕੀਮਤ ਬਹੁਤ ਕਠੋਰ ਹੈ. ਸਿਰਫ ਇਕ ਹੋਰ ਸੁਆਦੀ ਦੁਪਹਿਰ ਦਾ ਖਾਣਾ 150 ਤੋਂ 180 ਯੂਆਨ ਹੈ. ਮੈਂ 100 ਯੂਆਨ ਦੇ ਨਵੇਂ ਆਮੇ-ਦੁਆਲੇ ਗ੍ਰੈਜੂਏਟ ਕੀਤਾ. ਆਕਾਰ ਵਾਲੀ ਕੰਪਨੀ ਇਕ ਗ੍ਰਾਫਿਕ ਡਿਜ਼ਾਈਨਰ ਹੈ, ਜਿਸ ਵਿਚ 30,000 ਯੁਆਨ (ਲਗਭਗ 950 ਅਮਰੀਕੀ ਡਾਲਰ) ਦੀ ਮ
# ...

# %%
language.translate(from_lang='zh-CN', to='ta')
# Out:
# TextBlob("தைவானின் சம்பளம் 20 ஆண்டுகளாக நிறுத்தப்பட்டுள்ளது, முந்தைய அரசாங்கம் அதைத் தீர்ப்பதாக உறுதியளித்துள்ளது, ஆனால் மேம்படவில்லை. சில ஆய்வுகள் இளம் வாக்காளர்களுக்கு மிக முக்கியமான பிரச்சினைகளில் ஒன்றாகும் என்று சில ஆய்வுகள் காட்டுகின்றன. இது வேட்பாளர்கள் மீதான அழுத்தத்தை உருவாக்கும். நீண்ட காலமாக, ஜனநாயக அரசியலைப் பற்றிய தைவானின் இளைஞர்களின் நம்பிக்கையை சேதப்படுத்தும் வாய்ப்பு அதிகம். தைபேயில் குளிர்காலம் அதிகாலையில், 24 -ஆண்டு ஷியா (புனைப்பெயர்) ஜாங்ஜெங் மாவட்டத்தில் உள்ள அலுவலக கட்டிடத்திற்கு சைக்கிள் ஓட்டியது. இந்த 15 -மினிட் "டிரைவ்" மட்டுமே 5 யுவான் (nt $, கீழே) செலவாகும். அவர் நிருபரிடம் கூறினார்: "எப்படியிருந்தாலும், என் குடும்பம் நிறுவனத்திலிருந்து வெகு தொலைவில் இல்லை. போக்குவரத்து செலவுகளைச் சேமிப்பதில் கவனம் செலுத்துகிறது." அவர் பிங்டங்கில் இருந்து தைபேயில் தனியாக வேலை செய்தார், மேலும் துணிகளைச் சுருங்கும் வாழ்க்கையை வாழ்ந்தார். மதிய உணவு இடைவேளையில், அவர் அருகிலுள்ள பள்ளி மாவட்ட சிற்றுண்டி பட்டியில் ஓடி, 70 யுவான் இறைச்சி நூடுல்ஸின் கிண்ணத்தை ஆர்டர் செய்தார். "இப்போது
# ...

# %%
language.translate(from_lang='zh-CN', to='or')
# Out:
# TextBlob("ତାଇୱାନର ଦରମା 20 ବର୍ଷ ଧରି ଅଟକି ଯାଇଛି, ଏବଂ ପୂର୍ବ ସରକାର ଏହାକୁ ସମାଧାନ କରିବାକୁ ପ୍ରତିଜ୍ଞା କରିଛନ୍ତି, କିନ୍ତୁ ଉନ୍ନତି ହୋଇନାହିଁ | କିଛି ସର୍ବେକ୍ଷଣ ଶୋ ଯେ କମ୍ ଭଣ୍ଡାର ପାଇଁ ଏକ ଗୁରୁତ୍ୱପୂର୍ଣ୍ଣ ପ୍ରସଙ୍ଗ ମଧ୍ୟରୁ ଗୋଟିଏ | ଡେମୋକ୍ରାଟିକ୍ ରାଜନୀତିରେ ତାଇୱାନର ଚିତ୍ତାକର୍ଷକକୁ କ୍ଷତି ପହଞ୍ଚାଇବ | ତାଇପିରେ ପ୍ରଭାତରେ ଶୀତଦିନ ସକାଳେ, 24 -YER -LD ଶିଆ (ଛଦ୍ମନାମ) Zhonoudnym "zhondnym" zhondnym "ZUAN (NT $, ତଳେ) | ସେ ସାମ୍ବାଦିକଙ୍କୁ କହିଲେ: "ଯାହା ବି ହେଉ, ମୋ ପରିବାର କମ୍ପାନୀରୁ କିଛି ଦୂରରେ ନାହାଁନ୍ତି | ପରିବହନ ଖର୍ଚ୍ଚ ସଞ୍ଚୟ କରିବାରେ ଏବଂ ସଙ୍କୋଚନ ପୋଷାକରେ ଏକାକୀ କାମ କଲା | ମଧ୍ୟାହ୍ନ ଭୋଜନ ବିରତାରେ, ସେ ନିକଟସ୍ଥ ବିଦ୍ୟାଳୟ ଜିଲ୍ଲା ସ୍ନାକ୍ତ ବାରକୁ ଦ ran ଡ଼ିଗଲେ ଏବଂ ମାଂସ ନୁଡୁଲ୍ସର ଏକ ପାତ୍ରକୁ ଅଗ୍ରସର ହୋଇଥିଲେ | "ବର୍ତ୍ତମାନ ମୂଲ୍ୟ ବହୁତ ଭୟଙ୍କର ଅଟେ। କେବଳ ଏକ ସୁସ୍ବାଦୁ ମଧ୍ୟାହ୍ନ ଭୋଜନ ହେଉଛି 150 ୟୁଆନ୍। ମୁଁ ଛୋଟ ଏବଂ ମଧ୍ୟମରେ ଏକ ଅ and େଇ, SIZIZIZE କମ୍ପାନୀ ହେଉଛି 30,000 ୟୁଆନ୍ଙ୍କ ମଧ୍ୟରେ ଏକ ଗ୍ରାଫିକ୍ ଡିଜାଇନର୍ (ପ୍ରାୟ 950 ଆମେରିକୀୟ ଡଲାର) | କମ୍ପାନୀ ବେଳେବେଳେ 3000 ରୁ 6000 ରୁ 6,000 ୟୁଆନ୍ ଉପରେ ନିର୍ଭର କରେ |")

# %%
language.translate(from_lang='zh-CN', to='kn')
# Out:
# TextBlob("ತೈವಾನ್‌ನ ಸಂಬಳವು 20 ವರ್ಷಗಳಿಂದ ಸ್ಥಗಿತಗೊಂಡಿದೆ, ಮತ್ತು ಹಿಂದಿನ ಸರ್ಕಾರವು ಅದನ್ನು ಪರಿಹರಿಸುವ ಭರವಸೆ ನೀಡಿದೆ, ಆದರೆ ಸುಧಾರಿಸಿಲ್ಲ. ಕಡಿಮೆ -ಪಾವತಿಸುವ ಸಂದಿಗ್ಧತೆಯು ಯುವ ಮತದಾರರಿಗೆ ಒಂದು ಪ್ರಮುಖ ವಿಷಯವಾಗಿದೆ ಎಂದು ಕೆಲವು ಸಮೀಕ್ಷೆಗಳು ತೋರಿಸುತ್ತವೆ. ಇದು ಅಭ್ಯರ್ಥಿಗಳ ಮೇಲೆ ಒತ್ತಡವನ್ನುಂಟು ಮಾಡುತ್ತದೆ. ದೀರ್ಘಾವಧಿಯಲ್ಲಿ, ಪ್ರಜಾಪ್ರಭುತ್ವ ರಾಜಕೀಯದ ಬಗ್ಗೆ ತೈವಾನ್‌ನ ಯುವಕರ ವಿಶ್ವಾಸವನ್ನು ಇದು ಹಾನಿ ಮಾಡುವ ಸಾಧ್ಯತೆಯಿದೆ. ತೈಪೆಯಲ್ಲಿನ ಚಳಿಗಾಲದ ಮುಂಜಾನೆ, 24 -ವರ್ಷದ ಶಿಯಾ (ಕಾವ್ಯನಾಮ) ong ಾಂಗ್‌ಜೆಂಗ್ ಜಿಲ್ಲೆಯ ಕಚೇರಿ ಕಟ್ಟಡಕ್ಕೆ ಬೈಸಿಕಲ್ ಓಡಿಸಿದರು. ಈ 15 -ನಿಮಿಷ "ಡ್ರೈವ್" ಗೆ ಕೇವಲ 5 ಯುವಾನ್ (ಎನ್ಟಿ $, ಅದೇ ಕೆಳಗಿನ ಅದೇ) ವೆಚ್ಚವಾಗುತ್ತದೆ. ಅವರು ವರದಿಗಾರರಿಗೆ ಹೀಗೆ ಹೇಳಿದರು: "ಹೇಗಾದರೂ, ನನ್ನ ಕುಟುಂಬವು ಕಂಪನಿಯಿಂದ ದೂರದಲ್ಲಿಲ್ಲ. ಸಾರಿಗೆ ವೆಚ್ಚವನ್ನು ಉಳಿಸುವತ್ತ ಗಮನ ಹರಿಸಲಾಗಿದೆ." ಅವಳು ಪಿಂಗ್‌ಟಂಗ್‌ನಿಂದ ತೈಪೆಯಲ್ಲಿ ಏಕಾಂಗಿಯಾಗಿ ಕೆಲಸ ಮಾಡುತ್ತಿದ್ದಳು ಮತ್ತು ಕುಗ್ಗುತ್ತಿರುವ ಬಟ್ಟೆಗಳ ಜೀವನವನ್ನು ನಡೆಸುತ್ತಿದ್ದಳು. Lunch ಟದ ವಿರಾಮದ ಸಮಯದಲ್ಲಿ, ಅವರು ಹತ್ತಿರದ ಶಾಲಾ ಜಿಲ್ಲಾ ಸ್ನ್ಯಾಕ್ ಬಾರ್‌ಗೆ ಓಡಿ 70 ಯುವಾನ್ ಮಾಂಸದ ನೂಡಲ್ಸ್ ಬೌಲ್ ಅನ್ನು ಆದೇಶಿಸಿದರು. "ಈಗ ಬೆಲೆ ತುಂಬಾ ಉಗ್ರವಾಗಿದೆ. ಕೇವಲ ಹೆಚ್ಚು ರುಚಿಕರವಾದ lunch ಟವು 150 ರಿಂದ 180 ಯುವಾನ್ ಆ
# ...

# %%
language.translate(from_lang='zh-CN', to='te')
# Out:
# TextBlob("తైవాన్ జీతం 20 సంవత్సరాలుగా నిలిచిపోయింది, మరియు మునుపటి ప్రభుత్వం దీనిని పరిష్కరిస్తుందని వాగ్దానం చేసింది, కాని మెరుగుపరచలేదు. కొన్ని సర్వేలు యువ ఓటర్లకు తక్కువ చెల్లించే గందరగోళం చాలా ముఖ్యమైన సమస్యలలో ఒకటి అని చూపిస్తుంది. ఇది అభ్యర్థులపై ఒత్తిడిని కలిగిస్తుంది. దీర్ఘకాలంలో, ప్రజాస్వామ్య రాజకీయాల గురించి తైవాన్ యువత యొక్క విశ్వాసాన్ని దెబ్బతీసే అవకాశం ఉంది. తైపీలో శీతాకాలపు ఉదయాన్నే, 24 -సంవత్సరాల -అయోల్డ్ షియా (మారుపేరు) ong ోంగ్జెంగ్ జిల్లాలోని కార్యాలయ భవనానికి సైకిల్‌ను నడిపింది. ఈ 15 -నిమిషం "డ్రైవ్" కి 5 యువాన్ (NT $, క్రింద అదే) మాత్రమే ఖర్చవుతుంది. ఆమె రిపోర్టర్‌తో ఇలా చెప్పింది: "ఏమైనా, నా కుటుంబం సంస్థకు దూరంగా లేదు. రవాణా ఖర్చులను ఆదా చేయడంపై దృష్టి కేంద్రీకరించబడింది." ఆమె తైపీలో పింగ్తుంగ్ నుండి ఒంటరిగా పనిచేసింది మరియు కుంచించుకుపోతున్న బట్టలు గడిపింది. భోజన విరామ సమయంలో, ఆమె సమీపంలోని పాఠశాల జిల్లా స్నాక్ బార్‌కు పరిగెత్తి, 70 యువాన్ మాంసం నూడుల్స్ గిన్నెను ఆదేశించింది. "ఇప్పుడు ధర చాలా భయంకరమైనది. మరింత రుచికరమైన భోజనం 150 నుండి 180 యువాన్ల వరకు ఉంటుంది.
# ...

# %%
language.translate(from_lang='zh-CN', to='en')
# Out:
# TextBlob("Taiwan's salary has stalled for 20 years, and the previous government has promised to resolve it, but has not improved. Some surveys show that low -paying dilemma is one of the most important issues for young voters. It will constitute the pressure on candidates. In the long run, it is more likely to damage the confidence of Taiwan's youth about democratic politics. In the early winter morning in Taipei, the 24 -year -old Shiya (pseudonym) rode a bicycle to the office building in Zhongzheng District. This 15 -minute "drive" only costs 5 yuan (NT $, the same below). She said to the reporter: "Anyway, my family is not far from the company. The focus is on saving transportation expenses." She worked alone in Taipei from Pingtung and lived a life of shrinking clothes. At lunch break, she ran to a nearby school district snack bar and ordered a bowl of 70 yuan of meat noodles. "Now the price is very fierce. Just a more delicious lunch is 150 to 180 yuan. I want to compress the mo
# ...

# %%
language.translate(from_lang='zh-CN', to='fr')
# Out:
# TextBlob("Le salaire de Taiwan est au point mort depuis 20 ans et le gouvernement précédent a promis de le résoudre, mais ne s'est pas amélioré. Certaines enquêtes montrent que le dilemme à faible paiement est l'une des questions les plus importantes pour les jeunes électeurs. Cela constituera la pression sur les candidats. À long terme, il est plus susceptible d'endommager la confiance de la jeunesse de Taïwan sur la politique démocratique. Au début de l'hiver matin à Taipei, le Shiya (pseudonyme) de 24 ans (pseudonyme) a conduit un vélo vers l'immeuble de bureaux dans le district de Zhongzheng. Ce "drive" de 15 minutes ne coûte que 5 yuans (nt $, le même ci-dessous). Elle a dit au journaliste: "Quoi qu'il en soit, ma famille n'est pas loin de l'entreprise. L'accent est mis sur la sauvegarde des dépenses de transport." Elle a travaillé seule à Taipei de Pingtung et a vécu une vie de vêtements de rétrécissement. À la pause déjeuner, elle a couru vers un snack-bar à proximité du distr
# ...

# %%
language.translate(from_lang='zh-CN', to='sa')
# Out:
# TextBlob("ताइवानस्य वेतनं २० वर्षाणि यावत् स्थगितम्, पूर्वसर्वकारेण च तस्य समाधानस्य प्रतिज्ञा कृता, परन्तु न सुधरितम्। केचन सर्वेक्षणाः दर्शयन्ति यत् निम्न-भुक्तिः दुविधा-युक्तः युवा-मतदातानां कृते महत्त्वपूर्णेषु विषयेषु अन्यतमः अस्ति।एतत् अभ्यर्थीनां उपरि दबावस्य गठनं करिष्यति।दीर्घकालं यावत् ताइवान-युवानां लोकतान्त्रिकराजनीतेः विषये विश्वासस्य क्षतिः अधिका भवति। ताइपे-नगरस्य प्रातःकाले शीतकालीन-प्रभाते 24 -वर्षीयः शिया (छेदनाम) ज़ोङ्गझेङ्ग-मण्डले कार्यालय-भवनस्य सायकल-यानं कृतवान् ।एतत् 15 -minute "ड्राइव्" केवलं 5 युआन (NT $, अधः एव) भवति सा संवाददात्रीम् अवदत्- "किमपि, मम परिवारः कम्पनीतः दूरं नास्ति। परिवहनव्ययस्य रक्षणस्य विषये ध्यानं वर्तते।" मध्याह्नभोजनविरामसमये सा समीपस्थं विद्यालयजिल्हजलं प्रति धावित्वा ७० युआन् मीट् नूडल्स् इत्यस्य कटोराम् आज्ञापितवती । "अधुना मूल्यम् अतीव भयंकरम् अस्ति। केवलं अधिकं स्वादिष्टं मध्याह्नभोजनं १५० तः १८० युआन् अस्ति। अहं 100 युआन् मध्ये प्रतिभोजनं धनं संपीडयितुं इच्छामि।" कार्यस्थलस्य नवीनः वर्षः सार्धवर्षं यावत् स्नातकः अभवत्, लघुमध्यमरूप
# ...

# %%
# https://en.wikipedia.org/wiki/List_of_ISO_639_language_codes

# %%
punjabi = TextBlob("ਬੁੱਧਵਾਰ ਨੂੰ ਸੰਸਦ ਮੈਂਬਰ ਹਰਸਿਮਰਤ ਕੌਰ ਬਾਦਲ ਨੇ ਲੋਕ ਸਭਾ ਵਿਚ ਆਪਣੇ ਸੰਬੋਧਨ ਦੌਰਾਨ ਬੰਦੀ ਸਿੰਘਾਂ ਦੀ ਰਿਹਾਈ ਦਾ ਮੁੱਦਾ ਚੁੱਕਿਆ। ਇਸ ਉੱਤੇ ਕੇਂਦਰੀ ਮੰਤਰੀ ਅਮਿਤ ਸ਼ਾਹ ਨੇ ਜਵਾਬ ਦਿੰਦਿਆਂ ਕਿਹਾ ਕਿ ਜਿਸ ਵਿਅਕਤੀ ਨੂੰ ਆਪਣੇ ਵੱਲੋਂ ਕੀਤੇ ਗੁਨਾਹ ਦਾ ਪਛਤਾਵਾ ਨਹੀਂ ਹੈ, ਉਸ ਨੂੰ ਕਾਹਦੀ ਮੁਆਫੀ।'")

# %%
punjabi.translate(from_lang='pa', to='en')
# Out:
# TextBlob("Harsimrat Kaur Badal on Wednesday Mr. Badal has raised the issue of release of bandi Singhs during his address in the Lok Sabha. Replying to the Union Minister Amit Shah replicating that the person who does not regret his sin, a forgiveness. '")

# %%
punjabi.translate(from_lang='pa', to='hi')
# Out:
# TextBlob("हरसीमराट कौर बादल ने बुधवार को श्री बगल ने लोकसभा में अपने संबोधन के दौरान बांदी सिंह की रिहाई का मुद्दा उठाया है। केंद्रीय मंत्री अमित शाह को जवाब देते हुए कि वह व्यक्ति जो अपने पाप, माफी पर पछतावा नहीं करता है। '")

# %%
punjabi.translate(from_lang='pa', to='zh-CN')
# Out:
# TextBlob("Harsimrat Kaur Badal周三，Badal先生在Lok Sabha的讲话中提出了Bandi Singhs释放的问题。回答工会部长阿米特·沙阿（Amit Shah）复制说，那些不后悔罪的人，宽恕。")

# %%
a = TextBlob("I havv a gooood knowldge about NLP and I caan teachh youu.")

# %%
print("Incorrect and original text :", a)
print("************"*10)
print("Correct Text :", a.correct())
# Out:
# Incorrect and original text : I havv a gooood knowldge about NLP and I caan teachh youu.
# ************************************************************************************************************************
# Correct Text : I have a good knowledge about NLP and I can teach you.

# %% [markdown]
# # Text to speech

# %%
#!pip install gTTS

# %%
from gtts import gTTS

# %%
language = input("Enter your sentence here : \n>")
# Out:
# Enter your sentence here :
# >अमेरिकी राज्य कोलोराडो के सुप्रीम कोर्ट ने 2024 के राष्ट्रपति चुनाव में पूर्व राष्ट्रपति डोनाल्ड ट्रंप की फिर से दावेदारी पर रोक लगा दी है। उसने यह फैसला इस आधार पर दिया है कि उन्होंने ‘विद्रोह या बगावत’ में संलिप्त होने से जुड़े संवैधानिक प्रावधानों का उल्लंघन किया। चार बनाम 3 से हुए फैसले में अदालत ने पाया कि ट्रंप ने 6 जनवरी, 2021 को प्रदर्शनकारियों को उकसाने में जो भूमिका निभायी, उसके चलते वह अगले साल कोलोराडो में चुनावी बैलेट पर रहने के योग्य नहीं हैं। इन प्रदर्शनकारियों के एक हिस्से ने वॉशिंगटन में यू.एस. कैपिटल की इमारतों पर हमला किया था।

# %%
punjabi = gTTS(text=language, lang='fr')
punjabi.save('HINDI_french.mp3')

# %%
abc = TextBlob(language)

# %%
eng = abc.translate(from_lang='pa',to='en')

# %%
eng
# Out:
# TextBlob("The utterance of the umisphere of the American State Colette N 2024 is recovery in retailer resolution. This decision is on the basis of this decision as the basis of the ultro or garden of the rehabilitation, "the convicted provisions from the agreement. Four-calculations found in the court in the decision that it is notable to be held on the election balette in the year of the land. A part of these choices in the Washingtoning Ushingingtoning The roots of the capital is roamed.")

# %%
english = gTTS(text=eng, lang='en')
#english.save('eng.mp3')

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
example = "The Supreme Court of the U.S. State of Colorado has barred former President Donald Trump from running for office again in the 2024 presidential election, on the grounds that he violated a constitutional clause relating to engaging in an “insurrection or rebellion”. The court found, in a 4-3 split decision, that Mr. Trump was not eligible to be on the election ballot next year in Colorado for the role that he played in egging on protesters on January 6, 2021, a section of whom then went on to attack the buildings of the U.S. Capitol in Washington. The ruling sets a historical precedent for the use of Section 3 of the country’s 14th Amendment to strike a presidential candidate off the ballot — in this case the most popular Republican candidate by a significant margin and seen as highly likely to win the election. Under the Section (the “insurrection clause”), any person engaging in insurrection or rebellion against the U.S. Constitution shall not be permitted to run for public office including Congress, the military, and federal and state offices. The 14th Amendment, which was ratified in 1868, was established in part to disallow former Confederates from entering Congress and grabbing power from a government that they had previously fought. It is ironic that a similar post-Civil War logic might apply to Mr. Trump now, for his role in seeking to block the peaceful transfer of power to presidential incumbent, Joe Biden, on unproven allegations of election fraud linked to ballot voting. The Colorado ruling overturned an earlier district court verdict that declined to block Mr. Trump from contesting on the grounds that it was unclear whether the 14th Amendment covered the presidency."

# %%
example
# Out:
# 'The Supreme Court of the U.S. State of Colorado has barred former President Donald Trump from running for office again in the 2024 presidential election, on the grounds that he violated a constitutional clause relating to engaging in an “insurrection or rebellion”. The court found, in a 4-3 split decision, that Mr. Trump was not eligible to be on the election ballot next year in Colorado for the role that he played in egging on protesters on January 6, 2021, a section of whom then went on to attack the buildings of the U.S. Capitol in Washington. The ruling sets a historical precedent for the use of Section 3 of the country’s 14th Amendment to strike a presidential candidate off the ballot — in this case the most popular Republican candidate by a significant margin and seen as highly likely to win the election. Under the Section (the “insurrection clause”), any person engaging in insurrection or rebellion against the U.S. Constitution shall not be permitted to run for public office 
# ...

# %%
len(example)
# Out:
# 1706

# %%
word_tokenize(example)
# Out:
# ['The',
#  'Supreme',
#  'Court',
#  'of',
#  'the',
#  'U.S.',
#  'State',
#  'of',
#  'Colorado',
#  'has',
#  'barred',
#  'former',
#  'President',
#  'Donald',
#  'Trump',
#  'from',
#  'running',
#  'for',
#  'office',
#  'again',
#  'in',
#  'the',
#  '2024',
#  'presidential',
#  'election',
#  ',',
#  'on',
#  'the',
#  'grounds',
#  'that',
#  'he',
#  'violated',
#  'a',
#  'constitutional',
#  'clause',
#  'relating',
#  'to',
#  'engaging',
#  'in',
#  'an',
#  '“',
#  'insurrection',
#  'or',
#  'rebellion',
#  '”',
#  '.',
#  'The',
#  'court',
#  'found',
#  ',',
#  'in',
#  'a',
#  '4-3',
#  'split',
#  'decision',
#  ',',
#  'that',
#  'Mr.',
#  'Trump',
#  'was',
#  'not',
#  'eligible',
#  'to',
#  'be',
#  'on',
#  'the',
#  'election',
#  'ballot',
#  'next',
#  'year',
#  'in',
#  'Colorado',
#  'for',
#  'the',
#  'role',
#  'that',
#  'he',
#  'played',
#  'in',
#  'egging',
#  'on',
#  'protesters',
#  'on',
#  'January',
#  '6',
#  ',',
#  '2021',
#  ',',
# ...

# %%
len(word_tokenize(example))
# Out:
# 310

# %%
for word in word_tokenize(example):
    print(word)
# Out:
# The
# Supreme
# Court
# of
# the
# U.S.
# State
# of
# Colorado
# has
# barred
# former
# President
# Donald
# Trump
# from
# running
# for
# office
# again
# in
# the
# 2024
# presidential
# election
# ,
# on
# the
# grounds
# that
# he
# violated
# a
# constitutional
# clause
# relating
# to
# engaging
# in
# an
# “
# insurrection
# or
# rebellion
# ”
# .
# The
# court
# found
# ,
# in
# a
# 4-3
# split
# decision
# ,
# that
# Mr.
# Trump
# was
# not
# eligible
# to
# be
# on
# the
# election
# ballot
# next
# year
# in
# Colorado
# for
# the
# role
# that
# he
# played
# in
# egging
# on
# protesters
# on
# January
# 6
# ,
# 2021
# ,
# a
# section
# of
# whom
# then
# went
# on
# to
# attack
# the
# buildings
# of
# the
# U.S.
# Capitol
# in
# Washington
# .
# The
# ruling
# sets
# a
# historical
# precedent
# for
# the
# use
# of
# Section
# 3
# of
# the
# country
# ’
# s
# 14th
# Amendment
# to
# strike
# a
# presidential
# candidate
# off
# the
# ballot
# —
# in
# this
# case
# ...

# %% [markdown]
# # Whitespace Tokenizer

# %%
white_token = nltk.tokenize.WhitespaceTokenizer()

# %%
#white_token.tokenize(example)

# %%
len(white_token.tokenize(example))
# Out:
# 282

# %%
for white in white_token.tokenize(example):
    print(white)
# Out:
# The
# Supreme
# Court
# of
# the
# U.S.
# State
# of
# Colorado
# has
# barred
# former
# President
# Donald
# Trump
# from
# running
# for
# office
# again
# in
# the
# 2024
# presidential
# election,
# on
# the
# grounds
# that
# he
# violated
# a
# constitutional
# clause
# relating
# to
# engaging
# in
# an
# “insurrection
# or
# rebellion”.
# The
# court
# found,
# in
# a
# 4-3
# split
# decision,
# that
# Mr.
# Trump
# was
# not
# eligible
# to
# be
# on
# the
# election
# ballot
# next
# year
# in
# Colorado
# for
# the
# role
# that
# he
# played
# in
# egging
# on
# protesters
# on
# January
# 6,
# 2021,
# a
# section
# of
# whom
# then
# went
# on
# to
# attack
# the
# buildings
# of
# the
# U.S.
# Capitol
# in
# Washington.
# The
# ruling
# sets
# a
# historical
# precedent
# for
# the
# use
# of
# Section
# 3
# of
# the
# country’s
# 14th
# Amendment
# to
# strike
# a
# presidential
# candidate
# off
# the
# ballot
# —
# in
# this
# case
# the
# most
# popular
# ...

# %% [markdown]
# # Sentence tokenizer

# %%
sent_tokenize(example)
# Out:
# ['The Supreme Court of the U.S. State of Colorado has barred former President Donald Trump from running for office again in the 2024 presidential election, on the grounds that he violated a constitutional clause relating to engaging in an “insurrection or rebellion”.',
#  'The court found, in a 4-3 split decision, that Mr. Trump was not eligible to be on the election ballot next year in Colorado for the role that he played in egging on protesters on January 6, 2021, a section of whom then went on to attack the buildings of the U.S. Capitol in Washington.',
#  'The ruling sets a historical precedent for the use of Section 3 of the country’s 14th Amendment to strike a presidential candidate off the ballot — in this case the most popular Republican candidate by a significant margin and seen as highly likely to win the election.',
# ...

# %%
len(sent_tokenize(example))
# Out:
# 7

# %%
for sent in sent_tokenize(example):
    print(sent)
# Out:
# The Supreme Court of the U.S. State of Colorado has barred former President Donald Trump from running for office again in the 2024 presidential election, on the grounds that he violated a constitutional clause relating to engaging in an “insurrection or rebellion”.
# The court found, in a 4-3 split decision, that Mr. Trump was not eligible to be on the election ballot next year in Colorado for the role that he played in egging on protesters on January 6, 2021, a section of whom then went on to attack the buildings of the U.S. Capitol in Washington.
# The ruling sets a historical precedent for the use of Section 3 of the country’s 14th Amendment to strike a presidential candidate off the ballot — in this case the most popular Republican candidate by a significant margin and seen as highly likely to win the election.
# ...

# %% [markdown]
# # Stopwords

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
stopwords.words('hinglish')
# Out:
# ['a',
#  'aadi',
#  'aaj',
#  'aap',
#  'aapne',
#  'aata',
#  'aati',
#  'aaya',
#  'aaye',
#  'ab',
#  'abbe',
#  'abbey',
#  'abe',
#  'abhi',
#  'able',
#  'about',
#  'above',
#  'accha',
#  'according',
#  'accordingly',
#  'acha',
#  'achcha',
#  'across',
#  'actually',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'agar',
#  'ain',
#  'aint',
#  "ain't",
#  'aisa',
#  'aise',
#  'aisi',
#  'alag',
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'andar',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'ap',
#  'apan',
#  'apart',
#  'apna',
#  'apnaa',
#  'apne',
#  'apni',
#  'appear',
#  'are',
#  'aren',
#  'arent',
#  "aren't",
#  'around',
#  'arre',
#  'as',
#  'aside',
#  'ask',
#  'asking',
#  'at',
#  'aur',
#  'avum',
#  'aya',
#  'aye',
# ...

# %%
stopwords.words('french')
# Out:
# ['au',
#  'aux',
#  'avec',
#  'ce',
#  'ces',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'et',
#  'eux',
#  'il',
#  'ils',
#  'je',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'ma',
#  'mais',
#  'me',
#  'même',
#  'mes',
#  'moi',
#  'mon',
#  'ne',
#  'nos',
#  'notre',
#  'nous',
#  'on',
#  'ou',
#  'par',
#  'pas',
#  'pour',
#  'qu',
#  'que',
#  'qui',
#  'sa',
#  'se',
#  'ses',
#  'son',
#  'sur',
#  'ta',
#  'te',
#  'tes',
#  'toi',
#  'ton',
#  'tu',
#  'un',
#  'une',
#  'vos',
#  'votre',
#  'vous',
#  'c',
#  'd',
#  'j',
#  'l',
#  'à',
#  'm',
#  'n',
#  's',
#  't',
#  'y',
#  'été',
#  'étée',
#  'étées',
#  'étés',
#  'étant',
#  'étante',
#  'étants',
#  'étantes',
#  'suis',
#  'es',
#  'est',
#  'sommes',
#  'êtes',
#  'sont',
#  'serai',
#  'seras',
#  'sera',
#  'serons',
#  'serez',
#  'seront',
#  'serais',
#  'serait',
#  'serions',
#  'seriez',
#  'seraient',
#  'étais',
#  'était',
#  'étions',
#  'étiez',
#  'étaient',
# ...

# %%
stopwords.words('spanish')
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
# ...

# %% [markdown]
# # Word Cloud

# %%
# !pip install wordcloud
from wordcloud import WordCloud, STOPWORDS

# %%
stop_words = nltk.corpus.stopwords.words('english')
#stop_words

# %%
#example

# %%
wcloud = WordCloud(max_words=100, stopwords = stop_words)
wcloud.generate(example)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,14))
plt.imshow(wcloud)
plt.show()

# %%
wcloud = WordCloud(max_words=100, stopwords = stop_words, background_color='blue')
wcloud.generate(example)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,14))
plt.imshow(wcloud)
plt.show()

# %%
wcloud = WordCloud(max_words=100, stopwords = stop_words+["Trump","office",'court'], background_color='white')
wcloud.generate(example)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,14))
plt.imshow(wcloud)
plt.show()
